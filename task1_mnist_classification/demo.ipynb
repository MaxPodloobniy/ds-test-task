# %% [markdown]
# ### Importing Required Libraries
# We start by importing the necessary libraries for loading the MNIST dataset, visualizing the data, and working with our models.

# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.datasets import mnist
from MnistClassifier import MnistClassifier

# %% [markdown]
# ### Loading and Visualizing the Data
# The MNIST dataset consists of 28x28 grayscale images of handwritten digits (0-9). We will load the dataset and visualize a few examples.

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# Normalize pixel values to [0, 1]
x_train, x_test = x_train.astype("float32") / 255.0, x_test.astype("float32") / 255.0

def show_images(images, labels, num=10):
    plt.figure(figsize=(10, 5))
    for i in range(num):
        plt.subplot(2, 5, i + 1)
        plt.imshow(images[i], cmap="gray")
        plt.title(f"Label: {labels[i]}")
        plt.axis("off")
    plt.show()

show_images(x_train, y_train, num=10)

# %% [markdown]
# ## Evaluating Different Models
# We will initialize and train three different models:
# 1. Random Forest (rf)
# 2. Feed-Forward Neural Network (nn)
# 3. Convolutional Neural Network (cnn)
#
# After training, we will make predictions on a few test images.

# %% [markdown]
# ### Test Random Forest Model

# %%
rf_classifier = MnistClassifier(alg_type='rf')
rf_classifier.train()

print("Testing Random Forest Model:")
predictions = rf_classifier.predict()
indices = range(10)
show_images([x_test[i].reshape(28, 28) for i in indices], [predictions[i] for i in indices])
# Out:
# Training Random Forest Classifier...
# Accuracy of model on test dataset is 0.9704
# Testing Random Forest Model:

# %% [markdown]
# ### Test Feed-Forward Neural Network Model

# %%
nn_classifier = MnistClassifier(alg_type='nn')
nn_classifier.train()

print("Testing Feed-Forward Neural Network Model:")
predictions = nn_classifier.predict()
predictions = np.argmax(predictions, axis=1)
show_images([x_test[i].reshape(28, 28) for i in indices], [predictions[i] for i in indices])
# Out:
# Training Feed-Forward Classifier...
# Epoch 1/3
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.7967 - loss: 0.6484 - val_accuracy: 0.9584 - val_loss: 0.1347
# Epoch 2/3
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9395 - loss: 0.2051 - val_accuracy: 0.9677 - val_loss: 0.1044
# Epoch 3/3
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9542 - loss: 0.1563 - val_accuracy: 0.9711 - val_loss: 0.0977
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9659 - loss: 0.1133
# Accuracy of model on test dataset is 0.9710999727249146
# Testing Feed-Forward Neural Network Model:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step

# %% [markdown]
# ### Test Convolutional Neural Network Model

# %%
cnn_classifier = MnistClassifier(alg_type='cnn')
cnn_classifier.train()

print("Testing Convolutional Neural Network Model:")
predictions = cnn_classifier.predict()
predictions = np.argmax(predictions, axis=1)
show_images([x_test[i].reshape(28, 28) for i in indices], [predictions[i] for i in indices])
# Out:
# /Users/maxim/.pyenv/versions/3.9.13/envs/task1_ds_intership/lib/python3.9/site-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Training Convolutional NN Classifier...
# Epoch 1/5
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 30s 31ms/step - accuracy: 0.8860 - loss: 0.3731 - val_accuracy: 0.9849 - val_loss: 0.0487
# Epoch 2/5
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 28s 30ms/step - accuracy: 0.9856 - loss: 0.0468 - val_accuracy: 0.9880 - val_loss: 0.0355
# Epoch 3/5
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 29s 31ms/step - accuracy: 0.9902 - loss: 0.0318 - val_accuracy: 0.9886 - val_loss: 0.0360
# Epoch 4/5
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 28s 30ms/step - accuracy: 0.9923 - loss: 0.0240 - val_accuracy: 0.9893 - val_loss: 0.0322
# Epoch 5/5
# ...

# %% [markdown]
# ### Conclusion
# This notebook demonstrates the classification of handwritten digits using three different approaches: Random Forest, Feed-Forward Neural Network, and Convolutional Neural Network. Each model is implemented as a separate class, following an interface-based design pattern. The predictions showcase the varying performance and capabilities of different algorithms on the MNIST dataset.
